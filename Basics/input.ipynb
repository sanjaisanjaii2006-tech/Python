# %%
# input() , int(), float()
name = input("Enter an Name : ")
age = int(input("Enter Age :"))

# %%
print(name)
print(type(age))
# Out:
# vijay
# <class 'int'>

# %%
'''
excersise 1:

Get Student details:
1. Name
2. Age
3. City
4. Dept
5. Mobile no

Print the Details
'''

# %%
name, age, city, phone = input("Enter your Name : "), int(input("Enter your Age : ")),input("Enter your City ; "), int(input("Enter Phone No: : "))

# %%
print(f"Name : {name}")
print(f"Age : {age}")
print(f"City : {city}")
print(f"Phone : {phone}")
# Out:
# Name : vijay
# Age : 19
# City : Kallakurichi
# Phone : 6369853356

# %%
print("My name is --  ;", name)
# Out:
# My name is --  ; vijay

# %%
print("My name is", name, "All good")
# Out:
# My name is vijay All good

# %%
print(f"My name is {name}, My age is {age}, My city {city} All good")
# Out:
# My name is vijay, My age is 19, My city Kallakurichi All good

# %%
print (hello)
