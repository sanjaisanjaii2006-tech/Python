# %%
# input() , int(), float()
name = input("Enter an Name : ")
age = int(input("Enter Age :"))

# %%
print(name)
print(type(age))
# Out:
# vijay
# <class 'int'>

# %%
'''
excersise 1:

Get Student details:
1. Name
2. Age
3. City
4. Dept
5. Mobile no

Print the Details
'''
